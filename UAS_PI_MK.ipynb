# %% [markdown]
# ## Crawling

# %%
#crawling website hewania pada bagian blog, https://hewania.com/blog

import aiohttp
import asyncio
from bs4 import BeautifulSoup
import time

# Fungsi asynchronous untuk mengambil URL dari halaman tertentu
async def fetch_page(session, url, scraped_urls, max_links):
    async with session.get(url) as response:
        content = await response.text()
        soup = BeautifulSoup(content, 'html.parser')
        
        # Mencari elemen <h3> dengan kelas 'jeg_post_title'
        articles = soup.find_all('div', class_='btMediaBox')

        new_urls = []
        for article in articles:
            # Mendapatkan elemen <a> di dalam <h3> artikel
            article_link = article.find('a', href=True)
            if article_link:
                article_url = article_link['href']
                
                # Tambahkan URL jika belum di-scrape dan memenuhi jumlah link yang diminta
                if article_url not in scraped_urls and len(scraped_urls) < max_links:
                    scraped_urls.add(article_url)
                    new_urls.append(article_url)

        return new_urls

# Fungsi utama asynchronous untuk mengambil URL dari halaman kategori dan menyimpannya ke file
async def get_links_for_category(session, base_url, max_links, output_file):
    page_num = 1
    scraped_urls = set()
    total_links = 0

    with open(output_file, 'w', encoding='utf-8') as file:
        start_time = time.time()
        while total_links < max_links:
            url = f"{base_url}/page/{page_num}/"  # Navigasi antar halaman
            urls = await fetch_page(session, url, scraped_urls, max_links)

            # Hentikan jika tidak ada artikel ditemukan di halaman
            if not urls:
                print(f"Tidak ada artikel ditemukan di halaman {page_num}. Menghentikan pencarian.")
                break

            for article_url in urls:
                if total_links >= max_links:
                    break
                file.write(article_url + '\n')
                total_links += 1
                print(f"Link terkumpul di {output_file}: {total_links}")

            print(f"Halaman {page_num} untuk {output_file} selesai.")
            page_num += 1
            await asyncio.sleep(1)  # Delay kecil untuk menghindari overload

        end_time = time.time()
        duration = end_time - start_time
        print(f"Waktu yang dibutuhkan untuk {output_file}: {duration:.2f} detik.")

# Fungsi utama untuk mengambil URL dari kategori secara paralel
async def get_links_async(base_url, max_links):
    async with aiohttp.ClientSession() as session:
        output_file = "hewania_links.txt"
        await get_links_for_category(session, base_url, max_links, output_file)

# Fungsi untuk menjalankan asyncio di Jupyter Notebook atau lingkungan dengan event loop
async def main():
    base_url = "https://hewania.com/blog"
    max_links = 3000
    
    await get_links_async(base_url, max_links)

# Memanggil fungsi menggunakan event loop yang sedang berjalan
if __name__ == "__main__":
    try:
        await main()  # Untuk Jupyter atau lingkungan dengan event loop yang aktif
    except RuntimeError:  
        asyncio.run(main())  # Untuk lingkungan tanpa event loop
# Out:
# Link terkumpul di hewania_links.txt: 1
# Link terkumpul di hewania_links.txt: 2
# Link terkumpul di hewania_links.txt: 3
# Link terkumpul di hewania_links.txt: 4
# Link terkumpul di hewania_links.txt: 5
# Link terkumpul di hewania_links.txt: 6
# Link terkumpul di hewania_links.txt: 7
# Link terkumpul di hewania_links.txt: 8
# Link terkumpul di hewania_links.txt: 9
# Halaman 1 untuk hewania_links.txt selesai.
# Link terkumpul di hewania_links.txt: 10
# Link terkumpul di hewania_links.txt: 11
# Link terkumpul di hewania_links.txt: 12
# Link terkumpul di hewania_links.txt: 13
# Link terkumpul di hewania_links.txt: 14
# Link terkumpul di hewania_links.txt: 15
# Link terkumpul di hewania_links.txt: 16
# Link terkumpul di hewania_links.txt: 17
# Link terkumpul di hewania_links.txt: 18
# Link terkumpul di hewania_links.txt: 19
# Halaman 2 untuk hewania_links.txt selesai.
# Link terkumpul di hewania_links.txt:
# Link terkumpul di hewania_links.txt: 1510
# Link terkumpul di hewania_links.txt: 1511
# Link terkumpul di hewania_links.txt: 1512
# Link terkumpul di hewania_links.txt: 1513
# Halaman 155 untuk hewania_links.txt selesai.
# Tidak ada artikel ditemukan di halaman 156. Menghentikan pencarian.
# Waktu yang dibutuhkan untuk hewania_links.txt: 257.61 detik.

# %% [markdown]
# ## Scraping

# %%
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import csv
import time

# Fungsi asynchronous untuk melakukan scraping dari URL
async def scrape_link(session, link, writer, counter, semaphore):
    try:
        # Batasi jumlah koneksi bersamaan
        async with semaphore:
            async with session.get(link, timeout=10) as response:
                content = await response.text()
                soup = BeautifulSoup(content, 'html.parser')

                # Ambil judul
                title_element = soup.find('h1', class_='bt_bb_headline_tag')
                title = title_element.get_text(strip=True) if title_element else 'No title'

                # Ambil tanggal
                date_element = soup.find('span', class_='btArticleDate')
                date = date_element.get_text(strip=True) if date_element else 'No date'

                # Ambil konten
                content_element = soup.find('div', class_='btArticleContent')
                
                # Ambil hanya teks dari elemen <p> dan abaikan hyperlink di dalamnya
                if content_element:
                    paragraphs = content_element.find_all('p')
                    content = ' '.join([p.get_text(strip=True, separator=' ') for p in paragraphs if not p.find('a')])
                else:
                    content = 'No content'

                # Ambil URL gambar
                image_element = soup.find('div', class_='btMediaBox').find('img') if soup.find('div', class_='btMediaBox') else None
                image_url = image_element['src'] if image_element else 'No image'

                # Skip jika tidak ada konten
                if content == 'No content':
                    return

                # Menulis data ke CSV dengan menambahkan kolom gambar
                writer.writerow([link, title, date, content, image_url])
                counter['count'] += 1  # Increment count

                # Print setiap 1 link yang di-scrape
                if counter['count'] % 1 == 0:
                    print(f"{counter['count']} link berhasil di-scrape.")
    
    except asyncio.TimeoutError:
        print(f"Timeout error pada link: {link}")
    except Exception as e:
        print(f"Error pada link {link}: {e}")

# Fungsi utama untuk melakukan scraping dari satu file
async def scrape_from_links_async(input_file, csv_file):
    start_time = time.time()  # Mulai menghitung waktu

    with open(input_file, 'r', encoding='utf-8') as file:
        links = file.readlines()

    async with aiohttp.ClientSession() as session:
        # Membuka file CSV untuk menulis hasil scraping
        with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile, quoting=csv.QUOTE_ALL)  # Quote all fields
            writer.writerow(['Link', 'Judul', 'Tanggal', 'Content', 'Image URL'])  # Header CSV dengan kolom gambar
            
            # Daftar untuk menyimpan semua task
            tasks = []
            counter = {'count': 0}  # Counter untuk jumlah link yang di-scrape

            # Batasi jumlah koneksi bersamaan
            semaphore = asyncio.Semaphore(10)  # Batasi 10 koneksi bersamaan

            for link in links:
                link = link.strip()
                task = asyncio.create_task(scrape_link(session, link, writer, counter, semaphore))
                tasks.append(task)

            # Menunggu semua task selesai
            await asyncio.gather(*tasks)

    end_time = time.time()  # Akhir waktu
    duration = end_time - start_time
    print(f"Scraping selesai dalam {duration:.2f} detik.")

# Fungsi untuk menjalankan scraping pada file tunggal
def scrape():
    input_file = "hewania_links.txt"  # Ganti dengan file input yang sesuai
    output_file = "scraped_hewania_articles.csv"  # Nama file output CSV

    # Cek apakah event loop sudah berjalan
    try:
        loop = asyncio.get_running_loop()
    except RuntimeError:  # Tidak ada event loop yang berjalan
        asyncio.run(scrape_from_links_async(input_file, output_file))
    else:  # Event loop sedang berjalan
        loop.create_task(scrape_from_links_async(input_file, output_file))

# Memanggil fungsi untuk menjalankan scraping
scrape()
# Out:
# 1 link berhasil di-scrape.
# 2 link berhasil di-scrape.
# 3 link berhasil di-scrape.
# 4 link berhasil di-scrape.
# 5 link berhasil di-scrape.
# 6 link berhasil di-scrape.
# 7 link berhasil di-scrape.
# 8 link berhasil di-scrape.
# 9 link berhasil di-scrape.
# 10 link berhasil di-scrape.
# 11 link berhasil di-scrape.
# 12 link berhasil di-scrape.
# 13 link berhasil di-scrape.
# 14 link berhasil di-scrape.
# 15 link berhasil di-scrape.
# 16 link berhasil di-scrape.
# 17 link berhasil di-scrape.
# 18 link berhasil di-scrape.
# 19 link berhasil di-scrape.
# 20 link berhasil di-scrape.
# 21 link berhasil di-scrape.
# 22 link berhasil di-scrape.
# 23 link berhasil di-scrape.
# 24 link berhasil di-scrape.
# 25 link berhasil di-scrape.
# 26 link berhasil di-scrape.
# 27 link berhasil di-scrape.
# 28 link berhasil di-scrape.
# 29 link berhasil di-scrape.
# 30 link berhasil di-scrape.
# 31 link berhasil di-scrape.
# 32 link berhasil di-scrape.
# 33 link berhasil di-scrape.
# 34 link berhasil di-scrape.
# 35 link berhasil di-scrape.
# 36 link berhasil di-scrape.
# 37 link berhasil di-scrape.
# 38 link berhasil di-scrape.
# 39 link berhasil di-scrape.
# 40 link berhasil di-scrape.
# 41 link berhasil di-scrape.
# 42 link berhasil di-scrape.
# 43 link berhasil di-scrape.
# 44 link berhasil di-scrape.
# 45 link berhasil di-scrape.
# 46 link berhasil di-scrape.
# 47 link berhasil di-scrape.
# 48 link berhasil di-scrape.
# 49 link berhasil di-scrape.
# 50 link berhasil di-scrape.
# 51 link berhasil di-scrape.
# 52 link berhasil di-scrape.
# 53 link berhasil di-scrape.
# 54 link berhasil di-scrape.
# 55 link berhasil di-scrape.
# 56 link berhasil di-scrape.
# 57 link berhasil di-scrape.
# 58 link berhasil di-scrape.
# 59 link berhasil di-scrape.
# 60 link berhasil di-scrape.
# 61 link berhasil di-scrape.
# 62 link berhasil di-scrape.
# 63 link berhasil di-scrape.
# 64 link berhasil di-scrape.
# 65 link berhasil di-scrape.
# 66 link berhasil di-scrape.
# 67 link berhasil di-scrape.
# 68 link berhasil di-scrape.
# 69 link berhasil di-scrape.
# 70 link berhasil di-scrape.
# 71 link berhasil di-scrape.
# 72 link berhasil di-scrape.
# 73 link berhasil di-scrape.
# 74 link berhasil di-scrape.
# 75 link berhasil di-scrape.
# 76 link berhasil di-scrape.
# 77 link berhasil di-scrape.
# 78 link berhasil di-scrape.
# 79 link berhasil di-scrape.
# 80 link berhasil di-scrape.
# 81 link berhasil di-scrape.
# 82 link berhasil di-scrape.
# 83 link berhasil di-scrape.
# 84 link berhasil di-scrape.
# 85 link berhasil di-scrape.
# 86 link berhasil di-scrape.
# 87 link berhasil di-scrape.
# 88 link berhasil di-scrape.
# 89 link berhasil di-scrape.
# 90 link berhasil di-scrape.
# 91 link berhasil di-scrape.
# 92 link berhasil di-scrape.
# 93 link berhasil di-scrape.
# 94 link berhasil di-scrape.
# 95 link berhasil di-scrape.
# 96 link berhasil di-scrape.
# 97 link berhasil di-scrape.
# 98 link berhasil di-scrape.
# 99 link berhasil di-scrape.
# 100 link berhasil di-scrape.
# 101 link berhasil di-scrape.
# 102 link berhasil di-scrape.
# 103 link berhasil di-scrape.
# 104 link berhasil di-scrape.
# 105 link berhasil di-scrape.
# 106 link berhasil di-scrape.
# 107 link berhasil di-scrape.
# 108 link berhasil di-scrape.
# 109 link berhasil di-scrape.
# 110 link berhasil di-scrape.
# 111 link berhasil di-scrape.
# 112 link berhasil di-scrape.
# 113 link berhasil di-scrape.
# 114 link berhasil di-scrape.
# 115 link berhasil di-scrape.
# 116 link berhasil di-scrape.
# 117 link berhasil di-scrape.
# 118 link berhasil di-scrape.
# 119 link berhasil di-scrape.
# 120 link berhasil di-scrape.
# 121 link berhasil di-scrape.
# 122 link berhasil di-scrape.
# 123 link berhasil di-scrape.
# 124 link berhasil di-scrape.
# 125 link berhasil di-scrape.
# 126 link berhasil di-scrape.
# 127 link berhasil di-scrape.
# 128 link berhasil di-scrape.
# 129 link berhasil di-scrape.
# 130 link berhasil di-scrape.
# 131 link berhasil di-scrape.
# 132 link berhasil di-scrape.
# 133 link berhasil di-scrape.
# 134 link berhasil di-scrape.
# 135 link berhasil di-scrape.
# 136 link berhasil di-scrape.
# 137 link berhasil di-scrape.
# 138 link berhasil di-scrape.
# 139 link berhasil di-scrape.
# 140 link berhasil di-scrape.
# 141 link berhasil di-scrape.
# 142 link berhasil di-scrape.
# 143 link berhasil di-scrape.
# 144 link berhasil di-scrape.
# 145 link berhasil di-scrape.
# 146 link berhasil di-scrape.
# 147 link berhasil di-scrape.
# 148 link berhasil di-scrape.
# 149 link berhasil di-scrape.
# 150 link berhasil di-scrape.
# 151 link berhasil di-scrape.
# 152 link berhasil di-scrape.
# 153 link berhasil di-scrape.
# 154 link berhasil di-scrape.
# 155 link berhasil di-scrape.
# 156 link berhasil di-scrape.
# 157 link berhasil di-scrape.
# 158 link berhasil di-scrape.
# 159 link berhasil di-scrape.
# 160 link berhasil di-scrape.
# 161 link berhasil di-scrape.
# 162 link berhasil di-scrape.
# 163 link berhasil di-scrape.
# 164 link berhasil di-scrape.
# 165 link berhasil di-scrape.
# 166 link berhasil di-scrape.
# 167 link berhasil di-scrape.
# 168 link berhasil di-scrape.
# 169 link berhasil di-scrape.
# 170 link berhasil di-scrape.
# 171 link berhasil di-scrape.
# 172 link berhasil di-scrape.
# 173 link berhasil di-scrape.
# 174 link berhasil di-scrape.
# 175 link berhasil di-scrape.
# 176 link berhasil di-scrape.
# 177 link berhasil di-scrape.
# 178 link berhasil di-scrape.
# 179 link berhasil di-scrape.
# 180 link berhasil di-scrape.
# 181 link berhasil di-scrape.
# 182 link berhasil di-scrape.
# 183 link berhasil di-scrape.
# 184 link berhasil di-scrape.
# 185 link berhasil di-scrape.
# 186 link berhasil di-scrape.
# 187 link berhasil di-scrape.
# 188 link berhasil di-scrape.
# 189 link berhasil di-scrape.
# 190 link berhasil di-scrape.
# 191 link berhasil di-scrape.
# 192 link berhasil di-scrape.
# 193 link berhasil di-scrape.
# 194 link berhasil di-scrape.
# 195 link berhasil di-scrape.
# 196 link berhasil di-scrape.
# 197 link berhasil di-scrape.
# 198 link berhasil di-scrape.
# 199 link berhasil di-scrape.
# 200 link berhasil di-scrape.
# 201 link berhasil di-scrape.
# 202 link berhasil di-scrape.
# 203 link berhasil di-scrape.
# 204 link berhasil di-scrape.
# 205 link berhasil di-scrape.
# 206 link berhasil di-scrape.
# 207 link berhasil di-scrape.
# 208 link berhasil di-scrape.
# 209 link berhasil di-scrape.
# 210 link berhasil di-scrape.
# 211 link berhasil di-scrape.
# 212 link berhasil di-scrape.
# 213 link berhasil di-scrape.
# 214 link berhasil di-scrape.
# 215 link berhasil di-scrape.
# 216 link berhasil di-scrape.
# 217 link berhasil di-scrape.
# 218 link berhasil di-scrape.
# 219 link berhasil di-scrape.
# 220 link berhasil di-scrape.
# 221 link berhasil di-scrape.
# 222 link berhasil di-scrape.
# 223 link berhasil di-scrape.
# 224 link berhasil di-scrape.
# 225 link berhasil di-scrape.
# 226 link berhasil di-scrape.
# 227 link berhasil di-scrape.
# 228 link berhasil di-scrape.
# 229 link berhasil di-scrape.
# 230 link berhasil di-scrape.
# 231 link berhasil di-scrape.
# 232 link berhasil di-scrape.
# 233 link berhasil di-scrape.
# 234 link berhasil di-scrape.
# 235 link berhasil di-scrape.
# 236 link berhasil di-scrape.
# 237 link berhasil di-scrape.
# 238 link berhasil di-scrape.
# 239 link berhasil di-scrape.
# 240 link berhasil di-scrape.
# 241 link berhasil di-scrape.
# 242 link berhasil di-scrape.
# 243 link berhasil di-scrape.
# 244 link berhasil di-scrape.
# 245 link berhasil di-scrape.
# 246 link berhasil di-scrape.
# 247 link berhasil di-scrape.
# 248 link berhasil di-scrape.
# 249 link berhasil di-scrape.
# 250 link berhasil di-scrape.
# 251 link berhasil di-scrape.
# 252 link berhasil di-scrape.
# 253 link berhasil di-scrape.
# 254 link berhasil di-scrape.
# 255 link berhasil di-scrape.
# 256 link berhasil di-scrape.
# 257 link berhasil di-scrape.
# 258 link berhasil di-scrape.
# 259 link berhasil di-scrape.
# 260 link berhasil di-scrape.
# 261 link berhasil di-scrape.
# 262 link berhasil di-scrape.
# 263 link berhasil di-scrape.
# 264 link berhasil di-scrape.
# 265 link berhasil di-scrape.
# 266 link berhasil di-scrape.
# 267 link berhasil di-scrape.
# 268 link berhasil di-scrape.
# 269 link berhasil di-scrape.
# 270 link berhasil di-scrape.
# 271 link berhasil di-scrape.
# 272 link berhasil di-scrape.
# 273 link berhasil di-scrape.
# 274 link berhasil di-scrape.
# 275 link berhasil di-scrape.
# 276 link berhasil di-scrape.
# 277 link berhasil di-scrape.
# 278 link berhasil di-scrape.
# 279 link berhasil di-scrape.
# 280 link berhasil di-scrape.
# 281 link berhasil di-scrape.
# 282 link berhasil di-scrape.
# 283 link berhasil di-scrape.
# 284 link berhasil di-scrape.
# 285 link berhasil di-scrape.
# 286 link berhasil di-scrape.
# 287 link berhasil di-scrape.
# 288 link berhasil di-scrape.
# 289 link berhasil di-scrape.
# 290 link berhasil di-scrape.
# 291 link berhasil di-scrape.
# 292 link berhasil di-scrape.
# 293 link berhasil di-scrape.
# 294 link berhasil di-scrape.
# 295 link berhasil di-scrape.
# 296 link berhasil di-scrape.
# 297 link berhasil di-scrape.
# 298 link berhasil di-scrape.
# 299 link berhasil di-scrape.
# 300 link berhasil di-scrape.
# 301 link berhasil di-scrape.
# 302 link berhasil di-scrape.
# 303 link berhasil di-scrape.
# 304 link berhasil di-scrape.
# 305 link berhasil di-scrape.
# 306 link berhasil di-scrape.
# 307 link berhasil di-scrape.
# 308 link berhasil di-scrape.
# 309 link berhasil di-scrape.
# 310 link berhasil di-scrape.
# 311 link berhasil di-scrape.
# 312 link berhasil di-scrape.
# 313 link berhasil di-scrape.
# 314 link berhasil di-scrape.
# 315 link berhasil di-scrape.
# 316 link berhasil di-scrape.
# 317 link berhasil di-scrape.
# 318 link berhasil di-scrape.
# 319 link berhasil di-scrape.
# 320 link berhasil di-scrape.
# 321 link berhasil di-scrape.
# 322 link berhasil di-scrape.
# 323 link berhasil di-scrape.
# 324 link berhasil di-scrape.
# 325 link berhasil di-scrape.
# 326 link berhasil di-scrape.
# 327 link berhasil di-scrape.
# 328 link berhasil di-scrape.
# 329 link berhasil di-scrape.
# 330 link berhasil di-scrape.
# 331 link berhasil di-scrape.
# 332 link berhasil di-scrape.
# 333 link berhasil di-scrape.
# 334 link berhasil di-scrape.
# 335 link berhasil di-scrape.
# 336 link berhasil di-scrape.
# 337 link berhasil di-scrape.
# 338 link berhasil di-scrape.
# 339 link berhasil di-scrape.
# 340 link berhasil di-scrape.
# 341 link berhasil di-scrape.
# 342 link berhasil di-scrape.
# 343 link berhasil di-scrape.
# 344 link berhasil di-scrape.
# 345 link berhasil di-scrape.
# 346 link berhasil di-scrape.
# 347 link berhasil di-scrape.
# 348 link berhasil di-scrape.
# 349 link berhasil di-scrape.
# 350 link berhasil di-scrape.
# 351 link berhasil di-scrape.
# 352 link berhasil di-scrape.
# 353 link berhasil di-scrape.
# 354 link berhasil di-scrape.
# 355 link berhasil di-scrape.
# 356 link berhasil di-scrape.
# 357 link berhasil di-scrape.
# 358 link berhasil di-scrape.
# 359 link berhasil di-scrape.
# 360 link berhasil di-scrape.
# 361 link berhasil di-scrape.
# 362 link berhasil di-scrape.
# 363 link berhasil di-scrape.
# 364 link berhasil di-scrape.
# 365 link berhasil di-scrape.
# 366 link berhasil di-scrape.
# 367 link berhasil di-scrape.
# 368 link berhasil di-scrape.
# 369 link berhasil di-scrape.
# 370 link berhasil di-scrape.
# 371 link berhasil di-scrape.
# 372 link berhasil di-scrape.
# 373 link berhasil di-scrape.
# 374 link berhasil di-scrape.
# 375 link berhasil di-scrape.
# 376 link berhasil di-scrape.
# 377 link berhasil di-scrape.
# 378 link berhasil di-scrape.
# 379 link berhasil di-scrape.
# 380 link berhasil di-scrape.
# 381 link berhasil di-scrape.
# 382 link berhasil di-scrape.
# 383 link berhasil di-scrape.
# 384 link berhasil di-scrape.
# 385 link berhasil di-scrape.
# 386 link berhasil di-scrape.
# 387 link berhasil di-scrape.
# 388 link berhasil di-scrape.
# 389 link berhasil di-scrape.
# 390 link berhasil di-scrape.
# 391 link berhasil di-scrape.
# 392 link berhasil di-scrape.
# 393 link berhasil di-scrape.
# 394 link berhasil di-scrape.
# 395 link berhasil di-scrape.
# 396 link berhasil di-scrape.
# 397 link berhasil di-scrape.
# 398 link berhasil di-scrape.
# 399 link berhasil di-scrape.
# 400 link berhasil di-scrape.
# 401 link berhasil di-scrape.
# 402 link berhasil di-scrape.
# 403 link berhasil di-scrape.
# 404 link berhasil di-scrape.
# 405 link berhasil di-scrape.
# 406 link berhasil di-scrape.
# 407 link berhasil di-scrape.
# 408 link berhasil di-scrape.
# 409 link berhasil di-scrape.
# 410 link berhasil di-scrape.
# 411 link berhasil di-scrape.
# 412 link berhasil di-scrape.
# 413 link berhasil di-scrape.
# 414 link berhasil di-scrape.
# 415 link berhasil di-scrape.
# 416 link berhasil di-scrape.
# 417 link berhasil di-scrape.
# 418 link berhasil di-scrape.
# 419 link berhasil di-scrape.
# 420 link berhasil di-scrape.
# 421 link berhasil di-scrape.
# 422 link berhasil di-scrape.
# 423 link berhasil di-scrape.
# 424 link berhasil di-scrape.
# 425 link berhasil di-scrape.
# 426 link berhasil di-scrape.
# 427 link berhasil di-scrape.
# 428 link berhasil di-scrape.
# 429 link berhasil di-scrape.
# 430 link berhasil di-scrape.
# 431 link berhasil di-scrape.
# 432 link berhasil di-scrape.
# 433 link berhasil di-scrape.
# 434 link berhasil di-scrape.
# 435 link berhasil di-scrape.
# 436 link berhasil di-scrape.
# 437 link berhasil di-scrape.
# 438 link berhasil di-scrape.
# 439 link berhasil di-scrape.
# 440 link berhasil di-scrape.
# 441 link berhasil di-scrape.
# 442 link berhasil di-scrape.
# 443 link berhasil di-scrape.
# 444 link berhasil di-scrape.
# 445 link berhasil di-scrape.
# 446 link berhasil di-scrape.
# 447 link berhasil di-scrape.
# 448 link berhasil di-scrape.
# 449 link berhasil di-scrape.
# 450 link berhasil di-scrape.
# 451 link berhasil di-scrape.
# 452 link berhasil di-scrape.
# 453 link berhasil di-scrape.
# 454 link berhasil di-scrape.
# 455 link berhasil di-scrape.
# 456 link berhasil di-scrape.
# 457 link berhasil di-scrape.
# 458 link berhasil di-scrape.
# 459 link berhasil di-scrape.
# 460 link berhasil di-scrape.
# 461 link berhasil di-scrape.
# 462 link berhasil di-scrape.
# 463 link berhasil di-scrape.
# 464 link berhasil di-scrape.
# 465 link berhasil di-scrape.
# 466 link berhasil di-scrape.
# 467 link berhasil di-scrape.
# 468 link berhasil di-scrape.
# 469 link berhasil di-scrape.
# 470 link berhasil di-scrape.
# 471 link berhasil di-scrape.
# 472 link berhasil di-scrape.
# 473 link berhasil di-scrape.
# 474 link berhasil di-scrape.
# 475 link berhasil di-scrape.
# 476 link berhasil di-scrape.
# 477 link berhasil di-scrape.
# 478 link berhasil di-scrape.
# 479 link berhasil di-scrape.
# 480 link berhasil di-scrape.
# 481 link berhasil di-scrape.
# 482 link berhasil di-scrape.
# 483 link berhasil di-scrape.
# 484 link berhasil di-scrape.
# 485 link berhasil di-scrape.
# 486 link berhasil di-scrape.
# 487 link berhasil di-scrape.
# 488 link berhasil di-scrape.
# 489 link berhasil di-scrape.
# 490 link berhasil di-scrape.
# 491 link berhasil di-scrape.
# 492 link berhasil di-scrape.
# 493 link berhasil di-scrape.
# 494 link berhasil di-scrape.
# 495 link berhasil di-scrape.
# 496 link berhasil di-scrape.
# 497 link berhasil di-scrape.
# 498 link berhasil di-scrape.
# 499 link berhasil di-scrape.
# 500 link berhasil di-scrape.
# 501 link berhasil di-scrape.
# 502 link berhasil di-scrape.
# 503 link berhasil di-scrape.
# 504 link berhasil di-scrape.
# 505 link berhasil di-scrape.
# 506 link berhasil di-scrape.
# 507 link berhasil di-scrape.
# 508 link berhasil di-scrape.
# 509 link berhasil di-scrape.
# 510 link berhasil di-scrape.
# 511 link berhasil di-scrape.
# 512 link berhasil di-scrape.
# 513 link berhasil di-scrape.
# 514 link berhasil di-scrape.
# 515 link berhasil di-scrape.
# 516 link berhasil di-scrape.
# 517 link berhasil di-scrape.
# 518 link berhasil di-scrape.
# 519 link berhasil di-scrape.
# 520 link berhasil di-scrape.
# 521 link berhasil di-scrape.
# 522 link berhasil di-scrape.
# 523 link berhasil di-scrape.
# 524 link berhasil di-scrape.
# 525 link berhasil di-scrape.
# 526 link berhasil di-scrape.
# 527 link berhasil di-scrape.
# 528 link berhasil di-scrape.
# 529 link berhasil di-scrape.
# 530 link berhasil di-scrape.
# 531 link berhasil di-scrape.
# 532 link berhasil di-scrape.
# 533 link berhasil di-scrape.
# 534 link berhasil di-scrape.
# 535 link berhasil di-scrape.
# 536 link berhasil di-scrape.
# 537 link berhasil di-scrape.
# 538 link berhasil di-scrape.
# 539 link berhasil di-scrape.
# 540 link berhasil di-scrape.
# 541 link berhasil di-scrape.
# 542 link berhasil di-scrape.
# 543 link berhasil di-scrape.
# 544 link berhasil di-scrape.
# 545 link berhasil di-scrape.
# 546 link berhasil di-scrape.
# 547 link berhasil di-scrape.
# 548 link berhasil di-scrape.
# 549 link berhasil di-scrape.
# 550 link berhasil di-scrape.
# 551 link berhasil di-scrape.
# 552 link berhasil di-scrape.
# 553 link berhasil di-scrape.
# 554 link berhasil di-scrape.
# 555 link berhasil di-scrape.
# 556 link berhasil di-scrape.
# 557 link berhasil di-scrape.
# 558 link berhasil di-scrape.
# 559 link berhasil di-scrape.
# 560 link berhasil di-scrape.
# 561 link berhasil di-scrape.
# 562 link berhasil di-scrape.
# 563 link berhasil di-scrape.
# 564 link berhasil di-scrape.
# 565 link berhasil di-scrape.
# 566 link berhasil di-scrape.
# 567 link berhasil di-scrape.
# 568 link berhasil di-scrape.
# 569 link berhasil di-scrape.
# 570 link berhasil di-scrape.
# 571 link berhasil di-scrape.
# 572 link berhasil di-scrape.
# 573 link berhasil di-scrape.
# 574 link berhasil di-scrape.
# 575 link berhasil di-scrape.
# 576 link berhasil di-scrape.
# 577 link berhasil di-scrape.
# 578 link berhasil di-scrape.
# 579 link berhasil di-scrape.
# 580 link berhasil di-scrape.
# 581 link berhasil di-scrape.
# 582 link berhasil di-scrape.
# 583 link berhasil di-scrape.
# 584 link berhasil di-scrape.
# 585 link berhasil di-scrape.
# 586 link berhasil di-scrape.
# 587 link berhasil di-scrape.
# 588 link berhasil di-scrape.
# 589 link berhasil di-scrape.
# 590 link berhasil di-scrape.
# 591 link berhasil di-scrape.
# 592 link berhasil di-scrape.
# 593 link berhasil di-scrape.
# 594 link berhasil di-scrape.
# 595 link berhasil di-scrape.
# 596 link berhasil di-scrape.
# 597 link berhasil di-scrape.
# 598 link berhasil di-scrape.
# 599 link berhasil di-scrape.
# 600 link berhasil di-scrape.
# 601 link berhasil di-scrape.
# 602 link berhasil di-scrape.
# 603 link berhasil di-scrape.
# 604 link berhasil di-scrape.
# 605 link berhasil di-scrape.
# 606 link berhasil di-scrape.
# 607 link berhasil di-scrape.
# 608 link berhasil di-scrape.
# 609 link berhasil di-scrape.
# 610 link berhasil di-scrape.
# 611 link berhasil di-scrape.
# 612 link berhasil di-scrape.
# 613 link berhasil di-scrape.
# 614 link berhasil di-scrape.
# 615 link berhasil di-scrape.
# 616 link berhasil di-scrape.
# 617 link berhasil di-scrape.
# 618 link berhasil di-scrape.
# 619 link berhasil di-scrape.
# 620 link berhasil di-scrape.
# 621 link berhasil di-scrape.
# 622 link berhasil di-scrape.
# 623 link berhasil di-scrape.
# 624 link berhasil di-scrape.
# 625 link berhasil di-scrape.
# 626 link berhasil di-scrape.
# 627 link berhasil di-scrape.
# 628 link berhasil di-scrape.
# 629 link berhasil di-scrape.
# 630 link berhasil di-scrape.
# 631 link berhasil di-scrape.
# 632 link berhasil di-scrape.
# 633 link berhasil di-scrape.
# 634 link berhasil di-scrape.
# 635 link berhasil di-scrape.
# 636 link berhasil di-scrape.
# 637 link berhasil di-scrape.
# 638 link berhasil di-scrape.
# 639 link berhasil di-scrape.
# 640 link berhasil di-scrape.
# 641 link berhasil di-scrape.
# 642 link berhasil di-scrape.
# 643 link berhasil di-scrape.
# 644 link berhasil di-scrape.
# 645 link berhasil di-scrape.
# 646 link berhasil di-scrape.
# 647 link berhasil di-scrape.
# 648 link berhasil di-scrape.
# 649 link berhasil di-scrape.
# 650 link berhasil di-scrape.
# 651 link berhasil di-scrape.
# 652 link berhasil di-scrape.
# 653 link berhasil di-scrape.
# 654 link berhasil di-scrape.
# 655 link berhasil di-scrape.
# 656 link berhasil di-scrape.
# 657 link berhasil di-scrape.
# 658 link berhasil di-scrape.
# 659 link berhasil di-scrape.
# 660 link berhasil di-scrape.
# 661 link berhasil di-scrape.
# 662 link berhasil di-scrape.
# 663 link berhasil di-scrape.
# 664 link berhasil di-scrape.
# 665 link berhasil di-scrape.
# 666 link berhasil di-scrape.
# 667 link berhasil di-scrape.
# 668 link berhasil di-scrape.
# 669 link berhasil di-scrape.
# 670 link berhasil di-scrape.
# 671 link berhasil di-scrape.
# 672 link berhasil di-scrape.
# 673 link berhasil di-scrape.
# 674 link berhasil di-scrape.
# 675 link berhasil di-scrape.
# 676 link berhasil di-scrape.
# 677 link berhasil di-scrape.
# 678 link berhasil di-scrape.
# 679 link berhasil di-scrape.
# 680 link berhasil di-scrape.
# 681 link berhasil di-scrape.
# 682 link berhasil di-scrape.
# 683 link berhasil di-scrape.
# 684 link berhasil di-scrape.
# 685 link berhasil di-scrape.
# 686 link berhasil di-scrape.
# 687 link berhasil di-scrape.
# 688 link berhasil di-scrape.
# 689 link berhasil di-scrape.
# 690 link berhasil di-scrape.
# 691 link berhasil di-scrape.
# 692 link berhasil di-scrape.
# 693 link berhasil di-scrape.
# 694 link berhasil di-scrape.
# 695 link berhasil di-scrape.
# 696 link berhasil di-scrape.
# 697 link berhasil di-scrape.
# 698 link berhasil di-scrape.
# 699 link berhasil di-scrape.
# 700 link berhasil di-scrape.
# 701 link berhasil di-scrape.
# 702 link berhasil di-scrape.
# 703 link berhasil di-scrape.
# 704 link berhasil di-scrape.
# 705 link berhasil di-scrape.
# 706 link berhasil di-scrape.
# 707 link berhasil di-scrape.
# 708 link berhasil di-scrape.
# 709 link berhasil di-scrape.
# 710 link berhasil di-scrape.
# 711 link berhasil di-scrape.
# 712 link berhasil di-scrape.
# 713 link berhasil di-scrape.
# 714 link berhasil di-scrape.
# 715 link berhasil di-scrape.
# 716 link berhasil di-scrape.
# 717 link berhasil di-scrape.
# 718 link berhasil di-scrape.
# 719 link berhasil di-scrape.
# 720 link berhasil di-scrape.
# 721 link berhasil di-scrape.
# 722 link berhasil di-scrape.
# 723 link berhasil di-scrape.
# 724 link berhasil di-scrape.
# 725 link berhasil di-scrape.
# 726 link berhasil di-scrape.
# 727 link berhasil di-scrape.
# 728 link berhasil di-scrape.
# 729 link berhasil di-scrape.
# 730 link berhasil di-scrape.
# 731 link berhasil di-scrape.
# 732 link berhasil di-scrape.
# 733 link berhasil di-scrape.
# 734 link berhasil di-scrape.
# 735 link berhasil di-scrape.
# 736 link berhasil di-scrape.
# 737 link berhasil di-scrape.
# 738 link berhasil di-scrape.
# 739 link berhasil di-scrape.
# 740 link berhasil di-scrape.
# 741 link berhasil di-scrape.
# 742 link berhasil di-scrape.
# 743 link berhasil di-scrape.
# 744 link berhasil di-scrape.
# 745 link berhasil di-scrape.
# 746 link berhasil di-scrape.
# 747 link berhasil di-scrape.
# 748 link berhasil di-scrape.
# 749 link berhasil di-scrape.
# 750 link berhasil di-scrape.
# 751 link berhasil di-scrape.
# 752 link berhasil di-scrape.
# 753 link berhasil di-scrape.
# 754 link berhasil di-scrape.
# 755 link berhasil di-scrape.
# 756 link berhasil di-scrape.
# 757 link berhasil di-scrape.
# 758 link berhasil di-scrape.
# 759 link berhasil di-scrape.
# 760 link berhasil di-scrape.
# 761 link berhasil di-scrape.
# 762 link berhasil di-scrape.
# 763 link berhasil di-scrape.
# 764 link berhasil di-scrape.
# 765 link berhasil di-scrape.
# 766 link berhasil di-scrape.
# 767 link berhasil di-scrape.
# 768 link berhasil di-scrape.
# 769 link berhasil di-scrape.
# 770 link berhasil di-scrape.
# 771 link berhasil di-scrape.
# 772 link berhasil di-scrape.
# 773 link berhasil di-scrape.
# 774 link berhasil di-scrape.
# 775 link berhasil di-scrape.
# 776 link berhasil di-scrape.
# 777 link berhasil di-scrape.
# 778 link berhasil di-scrape.
# 779 link berhasil di-scrape.
# 780 link berhasil di-scrape.
# 781 link berhasil di-scrape.
# 782 link berhasil di-scrape.
# 783 link berhasil di-scrape.
# 784 link berhasil di-scrape.
# 785 link berhasil di-scrape.
# 786 link berhasil di-scrape.
# 787 link berhasil di-scrape.
# 788 link berhasil di-scrape.
# 789 link berhasil di-scrape.
# 790 link berhasil di-scrape.
# 791 link berhasil di-scrape.
# 792 link berhasil di-scrape.
# 793 link berhasil di-scrape.
# 794 link berhasil di-scrape.
# 795 link berhasil di-scrape.
# 796 link berhasil di-scrape.
# 797 link berhasil di-scrape.
# 798 link berhasil di-scrape.
# 799 link berhasil di-scrape.
# 800 link berhasil di-scrape.
# 801 link berhasil di-scrape.
# 802 link berhasil di-scrape.
# 803 link berhasil di-scrape.
# 804 link berhasil di-scrape.
# 805 link berhasil di-scrape.
# 806 link berhasil di-scrape.
# 807 link berhasil di-scrape.
# 808 link berhasil di-scrape.
# 809 link berhasil di-scrape.
# 810 link berhasil di-scrape.
# 811 link berhasil di-scrape.
# 812 link berhasil di-scrape.
# 813 link berhasil di-scrape.
# 814 link berhasil di-scrape.
# 815 link berhasil di-scrape.
# 816 link berhasil di-scrape.
# 817 link berhasil di-scrape.
# 818 link berhasil di-scrape.
# 819 link berhasil di-scrape.
# 820 link berhasil di-scrape.
# 821 link berhasil di-scrape.
# 822 link berhasil di-scrape.
# 823 link berhasil di-scrape.
# 824 link berhasil di-scrape.
# 825 link berhasil di-scrape.
# 826 link berhasil di-scrape.
# 827 link berhasil di-scrape.
# 828 link berhasil di-scrape.
# 829 link berhasil di-scrape.
# 830 link berhasil di-scrape.
# 831 link berhasil di-scrape.
# 832 link berhasil di-scrape.
# 833 link berhasil di-scrape.
# 834 link berhasil di-scrape.
# 835 link berhasil di-scrape.
# 836 link berhasil di-scrape.
# 837 link berhasil di-scrape.
# 838 link berhasil di-scrape.
# 839 link berhasil di-scrape.
# 840 link berhasil di-scrape.
# 841 link berhasil di-scrape.
# 842 link berhasil di-scrape.
# 843 link berhasil di-scrape.
# 844 link berhasil di-scrape.
# 845 link berhasil di-scrape.
# 846 link berhasil di-scrape.
# 847 link berhasil di-scrape.
# 848 link berhasil di-scrape.
# 849 link berhasil di-scrape.
# 850 link berhasil di-scrape.
# 851 link berhasil di-scrape.
# 852 link berhasil di-scrape.
# 853 link berhasil di-scrape.
# 854 link berhasil di-scrape.
# 855 link berhasil di-scrape.
# 856 link berhasil di-scrape.
# 857 link berhasil di-scrape.
# 858 link berhasil di-scrape.
# 859 link berhasil di-scrape.
# 860 link berhasil di-scrape.
# 861 link berhasil di-scrape.
# 862 link berhasil di-scrape.
# 863 link berhasil di-scrape.
# 864 link berhasil di-scrape.
# 865 link berhasil di-scrape.
# 866 link berhasil di-scrape.
# 867 link berhasil di-scrape.
# 868 link berhasil di-scrape.
# 869 link berhasil di-scrape.
# 870 link berhasil di-scrape.
# 871 link berhasil di-scrape.
# 872 link berhasil di-scrape.
# 873 link berhasil di-scrape.
# 874 link berhasil di-scrape.
# 875 link berhasil di-scrape.
# 876 link berhasil di-scrape.
# 877 link berhasil di-scrape.
# 878 link berhasil di-scrape.
# 879 link berhasil di-scrape.
# 880 link berhasil di-scrape.
# 881 link berhasil di-scrape.
# 882 link berhasil di-scrape.
# 883 link berhasil di-scrape.
# 884 link berhasil di-scrape.
# 885 link berhasil di-scrape.
# 886 link berhasil di-scrape.
# 887 link berhasil di-scrape.
# 888 link berhasil di-scrape.
# 889 link berhasil di-scrape.
# 890 link berhasil di-scrape.
# 891 link berhasil di-scrape.
# 892 link berhasil di-scrape.
# 893 link berhasil di-scrape.
# 894 link berhasil di-scrape.
# 895 link berhasil di-scrape.
# 896 link berhasil di-scrape.
# 897 link berhasil di-scrape.
# 898 link berhasil di-scrape.
# 899 link berhasil di-scrape.
# 900 link berhasil di-scrape.
# 901 link berhasil di-scrape.
# 902 link berhasil di-scrape.
# 903 link berhasil di-scrape.
# 904 link berhasil di-scrape.
# 905 link berhasil di-scrape.
# 906 link berhasil di-scrape.
# 907 link berhasil di-scrape.
# 908 link berhasil di-scrape.
# 909 link berhasil di-scrape.
# 910 link berhasil di-scrape.
# 911 link berhasil di-scrape.
# 912 link berhasil di-scrape.
# 913 link berhasil di-scrape.
# 914 link berhasil di-scrape.
# 915 link berhasil di-scrape.
# 916 link berhasil di-scrape.
# 917 link berhasil di-scrape.
# 918 link berhasil di-scrape.
# 919 link berhasil di-scrape.
# 920 link berhasil di-scrape.
# 921 link berhasil di-scrape.
# 922 link berhasil di-scrape.
# 923 link berhasil di-scrape.
# 924 link berhasil di-scrape.
# 925 link berhasil di-scrape.
# 926 link berhasil di-scrape.
# 927 link berhasil di-scrape.
# 928 link berhasil di-scrape.
# 929 link berhasil di-scrape.
# 930 link berhasil di-scrape.
# 931 link berhasil di-scrape.
# 932 link berhasil di-scrape.
# 933 link berhasil di-scrape.
# 934 link berhasil di-scrape.
# 935 link berhasil di-scrape.
# 936 link berhasil di-scrape.
# 937 link berhasil di-scrape.
# 938 link berhasil di-scrape.
# 939 link berhasil di-scrape.
# 940 link berhasil di-scrape.
# 941 link berhasil di-scrape.
# 942 link berhasil di-scrape.
# 943 link berhasil di-scrape.
# 944 link berhasil di-scrape.
# 945 link berhasil di-scrape.
# 946 link berhasil di-scrape.
# 947 link berhasil di-scrape.
# 948 link berhasil di-scrape.
# 949 link berhasil di-scrape.
# 950 link berhasil di-scrape.
# 951 link berhasil di-scrape.
# 952 link berhasil di-scrape.
# 953 link berhasil di-scrape.
# 954 link berhasil di-scrape.
# 955 link berhasil di-scrape.
# 956 link berhasil di-scrape.
# 957 link berhasil di-scrape.
# 958 link berhasil di-scrape.
# 959 link berhasil di-scrape.
# 960 link berhasil di-scrape.
# 961 link berhasil di-scrape.
# 962 link berhasil di-scrape.
# 963 link berhasil di-scrape.
# 964 link berhasil di-scrape.
# 965 link berhasil di-scrape.
# 966 link berhasil di-scrape.
# 967 link berhasil di-scrape.
# 968 link berhasil di-scrape.
# 969 link berhasil di-scrape.
# 970 link berhasil di-scrape.
# 971 link berhasil di-scrape.
# 972 link berhasil di-scrape.
# 973 link berhasil di-scrape.
# 974 link berhasil di-scrape.
# 975 link berhasil di-scrape.
# 976 link berhasil di-scrape.
# 977 link berhasil di-scrape.
# 978 link berhasil di-scrape.
# 979 link berhasil di-scrape.
# 980 link berhasil di-scrape.
# 981 link berhasil di-scrape.
# 982 link berhasil di-scrape.
# 983 link berhasil di-scrape.
# 984 link berhasil di-scrape.
# 985 link berhasil di-scrape.
# 986 link berhasil di-scrape.
# 987 link berhasil di-scrape.
# 988 link berhasil di-scrape.
# 989 link berhasil di-scrape.
# 990 link berhasil di-scrape.
# 991 link berhasil di-scrape.
# 992 link berhasil di-scrape.
# 993 link berhasil di-scrape.
# 994 link berhasil di-scrape.
# 995 link berhasil di-scrape.
# 996 link berhasil di-scrape.
# 997 link berhasil di-scrape.
# 998 link berhasil di-scrape.
# 999 link berhasil di-scrape.
# 1000 link berhasil di-scrape.
# 1001 link berhasil di-scrape.
# 1002 link berhasil di-scrape.
# 1003 link berhasil di-scrape.
# 1004 link berhasil di-scrape.
# 1005 link berhasil di-scrape.
# 1006 link berhasil di-scrape.
# 1007 link berhasil di-scrape.
# 1008 link berhasil di-scrape.
# 1009 link berhasil di-scrape.
# 1010 link berhasil di-scrape.
# 1011 link berhasil di-scrape.
# 1012 link berhasil di-scrape.
# 1013 link berhasil di-scrape.
# 1014 link berhasil di-scrape.
# 1015 link berhasil di-scrape.
# 1016 link berhasil di-scrape.
# 1017 link berhasil di-scrape.
# 1018 link berhasil di-scrape.
# 1019 link berhasil di-scrape.
# 1020 link berhasil di-scrape.
# 1021 link berhasil di-scrape.
# 1022 link berhasil di-scrape.
# 1023 link berhasil di-scrape.
# 1024 link berhasil di-scrape.
# 1025 link berhasil di-scrape.
# 1026 link berhasil di-scrape.
# 1027 link berhasil di-scrape.
# 1028 link berhasil di-scrape.
# 1029 link berhasil di-scrape.
# 1030 link berhasil di-scrape.
# 1031 link berhasil di-scrape.
# 1032 link berhasil di-scrape.
# 1033 link berhasil di-scrape.
# 1034 link berhasil di-scrape.
# 1035 link berhasil di-scrape.
# 1036 link berhasil di-scrape.
# 1037 link berhasil di-scrape.
# 1038 link berhasil di-scrape.
# 1039 link berhasil di-scrape.
# 1040 link berhasil di-scrape.
# 1041 link berhasil di-scrape.
# 1042 link berhasil di-scrape.
# 1043 link berhasil di-scrape.
# 1044 link berhasil di-scrape.
# 1045 link berhasil di-scrape.
# 1046 link berhasil di-scrape.
# 1047 link berhasil di-scrape.
# 1048 link berhasil di-scrape.
# 1049 link berhasil di-scrape.
# 1050 link berhasil di-scrape.
# 1051 link berhasil di-scrape.
# 1052 link berhasil di-scrape.
# 1053 link berhasil di-scrape.
# 1054 link berhasil di-scrape.
# 1055 link berhasil di-scrape.
# 1056 link berhasil di-scrape.
# 1057 link berhasil di-scrape.
# 1058 link berhasil di-scrape.
# 1059 link berhasil di-scrape.
# 1060 link berhasil di-scrape.
# 1061 link berhasil di-scrape.
# 1062 link berhasil di-scrape.
# 1063 link berhasil di-scrape.
# 1064 link berhasil di-scrape.
# 1065 link berhasil di-scrape.
# 1066 link berhasil di-scrape.
# 1067 link berhasil di-scrape.
# 1068 link berhasil di-scrape.
# 1069 link berhasil di-scrape.
# 1070 link berhasil di-scrape.
# 1071 link berhasil di-scrape.
# 1072 link berhasil di-scrape.
# 1073 link berhasil di-scrape.
# 1074 link berhasil di-scrape.
# 1075 link berhasil di-scrape.
# 1076 link berhasil di-scrape.
# 1077 link berhasil di-scrape.
# 1078 link berhasil di-scrape.
# 1079 link berhasil di-scrape.
# 1080 link berhasil di-scrape.
# 1081 link berhasil di-scrape.
# 1082 link berhasil di-scrape.
# 1083 link berhasil di-scrape.
# 1084 link berhasil di-scrape.
# 1085 link berhasil di-scrape.
# 1086 link berhasil di-scrape.
# 1087 link berhasil di-scrape.
# 1088 link berhasil di-scrape.
# 1089 link berhasil di-scrape.
# 1090 link berhasil di-scrape.
# 1091 link berhasil di-scrape.
# 1092 link berhasil di-scrape.
# 1093 link berhasil di-scrape.
# 1094 link berhasil di-scrape.
# 1095 link berhasil di-scrape.
# 1096 link berhasil di-scrape.
# 1097 link berhasil di-scrape.
# 1098 link berhasil di-scrape.
# 1099 link berhasil di-scrape.
# 1100 link berhasil di-scrape.
# 1101 link berhasil di-scrape.
# 1102 link berhasil di-scrape.
# 1103 link berhasil di-scrape.
# 1104 link berhasil di-scrape.
# 1105 link berhasil di-scrape.
# 1106 link berhasil di-scrape.
# 1107 link berhasil di-scrape.
# 1108 link berhasil di-scrape.
# 1109 link berhasil di-scrape.
# 1110 link berhasil di-scrape.
# 1111 link berhasil di-scrape.
# 1112 link berhasil di-scrape.
# 1113 link berhasil di-scrape.
# 1114 link berhasil di-scrape.
# 1115 link berhasil di-scrape.
# 1116 link berhasil di-scrape.
# 1117 link berhasil di-scrape.
# 1118 link berhasil di-scrape.
# 1119 link berhasil di-scrape.
# 1120 link berhasil di-scrape.
# 1121 link berhasil di-scrape.
# 1122 link berhasil di-scrape.
# 1123 link berhasil di-scrape.
# 1124 link berhasil di-scrape.
# 1125 link berhasil di-scrape.
# 1126 link berhasil di-scrape.
# 1127 link berhasil di-scrape.
# 1128 link berhasil di-scrape.
# 1129 link berhasil di-scrape.
# 1130 link berhasil di-scrape.
# 1131 link berhasil di-scrape.
# 1132 link berhasil di-scrape.
# 1133 link berhasil di-scrape.
# 1134 link berhasil di-scrape.
# 1135 link berhasil di-scrape.
# 1136 link berhasil di-scrape.
# 1137 link berhasil di-scrape.
# 1138 link berhasil di-scrape.
# 1139 link berhasil di-scrape.
# 1140 link berhasil di-scrape.
# 1141 link berhasil di-scrape.
# 1142 link berhasil di-scrape.
# 1143 link berhasil di-scrape.
# 1144 link berhasil di-scrape.
# 1145 link berhasil di-scrape.
# 1146 link berhasil di-scrape.
# 1147 link berhasil di-scrape.
# 1148 link berhasil di-scrape.
# 1149 link berhasil di-scrape.
# 1150 link berhasil di-scrape.
# 1151 link berhasil di-scrape.
# 1152 link berhasil di-scrape.
# 1153 link berhasil di-scrape.
# 1154 link berhasil di-scrape.
# 1155 link berhasil di-scrape.
# 1156 link berhasil di-scrape.
# 1157 link berhasil di-scrape.
# 1158 link berhasil di-scrape.
# 1159 link berhasil di-scrape.
# 1160 link berhasil di-scrape.
# 1161 link berhasil di-scrape.
# 1162 link berhasil di-scrape.
# 1163 link berhasil di-scrape.
# 1164 link berhasil di-scrape.
# 1165 link berhasil di-scrape.
# 1166 link berhasil di-scrape.
# 1167 link berhasil di-scrape.
# 1168 link berhasil di-scrape.
# 1169 link berhasil di-scrape.
# 1170 link berhasil di-scrape.
# 1171 link berhasil di-scrape.
# 1172 link berhasil di-scrape.
# 1173 link berhasil di-scrape.
# 1174 link berhasil di-scrape.
# 1175 link berhasil di-scrape.
# 1176 link berhasil di-scrape.
# 1177 link berhasil di-scrape.
# 1178 link berhasil di-scrape.
# 1179 link berhasil di-scrape.
# 1180 link berhasil di-scrape.
# 1181 link berhasil di-scrape.
# 1182 link berhasil di-scrape.
# 1183 link berhasil di-scrape.
# 1184 link berhasil di-scrape.
# 1185 link berhasil di-scrape.
# 1186 link berhasil di-scrape.
# 1187 link berhasil di-scrape.
# 1188 link berhasil di-scrape.
# 1189 link berhasil di-scrape.
# 1190 link berhasil di-scrape.
# 1191 link berhasil di-scrape.
# 1192 link berhasil di-scrape.
# 1193 link berhasil di-scrape.
# 1194 link berhasil di-scrape.
# 1195 link berhasil di-scrape.
# 1196 link berhasil di-scrape.
# 1197 link berhasil di-scrape.
# 1198 link berhasil di-scrape.
# 1199 link berhasil di-scrape.
# 1200 link berhasil di-scrape.
# 1201 link berhasil di-scrape.
# 1202 link berhasil di-scrape.
# 1203 link berhasil di-scrape.
# 1204 link berhasil di-scrape.
# 1205 link berhasil di-scrape.
# 1206 link berhasil di-scrape.
# 1207 link berhasil di-scrape.
# 1208 link berhasil di-scrape.
# 1209 link berhasil di-scrape.
# 1210 link berhasil di-scrape.
# 1211 link berhasil di-scrape.
# 1212 link berhasil di-scrape.
# 1213 link berhasil di-scrape.
# 1214 link berhasil di-scrape.
# 1215 link berhasil di-scrape.
# 1216 link berhasil di-scrape.
# 1217 link berhasil di-scrape.
# 1218 link berhasil di-scrape.
# 1219 link berhasil di-scrape.
# 1220 link berhasil di-scrape.
# 1221 link berhasil di-scrape.
# 1222 link berhasil di-scrape.
# 1223 link berhasil di-scrape.
# 1224 link berhasil di-scrape.
# 1225 link berhasil di-scrape.
# 1226 link berhasil di-scrape.
# 1227 link berhasil di-scrape.
# 1228 link berhasil di-scrape.
# 1229 link berhasil di-scrape.
# 1230 link berhasil di-scrape.
# 1231 link berhasil di-scrape.
# 1232 link berhasil di-scrape.
# 1233 link berhasil di-scrape.
# 1234 link berhasil di-scrape.
# 1235 link berhasil di-scrape.
# 1236 link berhasil di-scrape.
# 1237 link berhasil di-scrape.
# 1238 link berhasil di-scrape.
# 1239 link berhasil di-scrape.
# 1240 link berhasil di-scrape.
# 1241 link berhasil di-scrape.
# 1242 link berhasil di-scrape.
# 1243 link berhasil di-scrape.
# 1244 link berhasil di-scrape.
# 1245 link berhasil di-scrape.
# 1246 link berhasil di-scrape.
# 1247 link berhasil di-scrape.
# 1248 link berhasil di-scrape.
# 1249 link berhasil di-scrape.
# 1250 link berhasil di-scrape.
# 1251 link berhasil di-scrape.
# 1252 link berhasil di-scrape.
# 1253 link berhasil di-scrape.
# 1254 link berhasil di-scrape.
# 1255 link berhasil di-scrape.
# 1256 link berhasil di-scrape.
# 1257 link berhasil di-scrape.
# 1258 link berhasil di-scrape.
# 1259 link berhasil di-scrape.
# 1260 link berhasil di-scrape.
# 1261 link berhasil di-scrape.
# 1262 link berhasil di-scrape.
# 1263 link berhasil di-scrape.
# 1264 link berhasil di-scrape.
# 1265 link berhasil di-scrape.
# 1266 link berhasil di-scrape.
# 1267 link berhasil di-scrape.
# 1268 link berhasil di-scrape.
# 1269 link berhasil di-scrape.
# 1270 link berhasil di-scrape.
# 1271 link berhasil di-scrape.
# 1272 link berhasil di-scrape.
# 1273 link berhasil di-scrape.
# 1274 link berhasil di-scrape.
# 1275 link berhasil di-scrape.
# 1276 link berhasil di-scrape.
# 1277 link berhasil di-scrape.
# 1278 link berhasil di-scrape.
# 1279 link berhasil di-scrape.
# 1280 link berhasil di-scrape.
# 1281 link berhasil di-scrape.
# 1282 link berhasil di-scrape.
# 1283 link berhasil di-scrape.
# 1284 link berhasil di-scrape.
# 1285 link berhasil di-scrape.
# 1286 link berhasil di-scrape.
# 1287 link berhasil di-scrape.
# 1288 link berhasil di-scrape.
# 1289 link berhasil di-scrape.
# 1290 link berhasil di-scrape.
# 1291 link berhasil di-scrape.
# 1292 link berhasil di-scrape.
# 1293 link berhasil di-scrape.
# 1294 link berhasil di-scrape.
# 1295 link berhasil di-scrape.
# 1296 link berhasil di-scrape.
# 1297 link berhasil di-scrape.
# 1298 link berhasil di-scrape.
# 1299 link berhasil di-scrape.
# 1300 link berhasil di-scrape.
# 1301 link berhasil di-scrape.
# 1302 link berhasil di-scrape.
# 1303 link berhasil di-scrape.
# 1304 link berhasil di-scrape.
# 1305 link berhasil di-scrape.
# 1306 link berhasil di-scrape.
# 1307 link berhasil di-scrape.
# 1308 link berhasil di-scrape.
# 1309 link berhasil di-scrape.
# 1310 link berhasil di-scrape.
# 1311 link berhasil di-scrape.
# 1312 link berhasil di-scrape.
# 1313 link berhasil di-scrape.
# 1314 link berhasil di-scrape.
# 1315 link berhasil di-scrape.
# 1316 link berhasil di-scrape.
# 1317 link berhasil di-scrape.
# 1318 link berhasil di-scrape.
# 1319 link berhasil di-scrape.
# 1320 link berhasil di-scrape.
# 1321 link berhasil di-scrape.
# 1322 link berhasil di-scrape.
# 1323 link berhasil di-scrape.
# 1324 link berhasil di-scrape.
# 1325 link berhasil di-scrape.
# 1326 link berhasil di-scrape.
# 1327 link berhasil di-scrape.
# 1328 link berhasil di-scrape.
# 1329 link berhasil di-scrape.
# 1330 link berhasil di-scrape.
# 1331 link berhasil di-scrape.
# 1332 link berhasil di-scrape.
# 1333 link berhasil di-scrape.
# 1334 link berhasil di-scrape.
# 1335 link berhasil di-scrape.
# 1336 link berhasil di-scrape.
# 1337 link berhasil di-scrape.
# 1338 link berhasil di-scrape.
# 1339 link berhasil di-scrape.
# 1340 link berhasil di-scrape.
# 1341 link berhasil di-scrape.
# 1342 link berhasil di-scrape.
# 1343 link berhasil di-scrape.
# 1344 link berhasil di-scrape.
# 1345 link berhasil di-scrape.
# 1346 link berhasil di-scrape.
# 1347 link berhasil di-scrape.
# 1348 link berhasil di-scrape.
# 1349 link berhasil di-scrape.
# 1350 link berhasil di-scrape.
# 1351 link berhasil di-scrape.
# 1352 link berhasil di-scrape.
# 1353 link berhasil di-scrape.
# 1354 link berhasil di-scrape.
# 1355 link berhasil di-scrape.
# 1356 link berhasil di-scrape.
# 1357 link berhasil di-scrape.
# 1358 link berhasil di-scrape.
# 1359 link berhasil di-scrape.
# 1360 link berhasil di-scrape.
# 1361 link berhasil di-scrape.
# 1362 link berhasil di-scrape.
# 1363 link berhasil di-scrape.
# 1364 link berhasil di-scrape.
# 1365 link berhasil di-scrape.
# 1366 link berhasil di-scrape.
# 1367 link berhasil di-scrape.
# 1368 link berhasil di-scrape.
# 1369 link berhasil di-scrape.
# 1370 link berhasil di-scrape.
# 1371 link berhasil di-scrape.
# 1372 link berhasil di-scrape.
# 1373 link berhasil di-scrape.
# 1374 link berhasil di-scrape.
# 1375 link berhasil di-scrape.
# 1376 link berhasil di-scrape.
# 1377 link berhasil di-scrape.
# 1378 link berhasil di-scrape.
# 1379 link berhasil di-scrape.
# 1380 link berhasil di-scrape.
# 1381 link berhasil di-scrape.
# 1382 link berhasil di-scrape.
# 1383 link berhasil di-scrape.
# 1384 link berhasil di-scrape.
# 1385 link berhasil di-scrape.
# 1386 link berhasil di-scrape.
# 1387 link berhasil di-scrape.
# 1388 link berhasil di-scrape.
# 1389 link berhasil di-scrape.
# 1390 link berhasil di-scrape.
# 1391 link berhasil di-scrape.
# 1392 link berhasil di-scrape.
# 1393 link berhasil di-scrape.
# 1394 link berhasil di-scrape.
# 1395 link berhasil di-scrape.
# 1396 link berhasil di-scrape.
# 1397 link berhasil di-scrape.
# 1398 link berhasil di-scrape.
# 1399 link berhasil di-scrape.
# 1400 link berhasil di-scrape.
# 1401 link berhasil di-scrape.
# 1402 link berhasil di-scrape.
# 1403 link berhasil di-scrape.
# 1404 link berhasil di-scrape.
# 1405 link berhasil di-scrape.
# 1406 link berhasil di-scrape.
# 1407 link berhasil di-scrape.
# 1408 link berhasil di-scrape.
# 1409 link berhasil di-scrape.
# 1410 link berhasil di-scrape.
# 1411 link berhasil di-scrape.
# 1412 link berhasil di-scrape.
# 1413 link berhasil di-scrape.
# 1414 link berhasil di-scrape.
# 1415 link berhasil di-scrape.
# 1416 link berhasil di-scrape.
# 1417 link berhasil di-scrape.
# 1418 link berhasil di-scrape.
# 1419 link berhasil di-scrape.
# 1420 link berhasil di-scrape.
# 1421 link berhasil di-scrape.
# 1422 link berhasil di-scrape.
# 1423 link berhasil di-scrape.
# 1424 link berhasil di-scrape.
# 1425 link berhasil di-scrape.
# 1426 link berhasil di-scrape.
# 1427 link berhasil di-scrape.
# 1428 link berhasil di-scrape.
# 1429 link berhasil di-scrape.
# 1430 link berhasil di-scrape.
# 1431 link berhasil di-scrape.
# 1432 link berhasil di-scrape.
# 1433 link berhasil di-scrape.
# 1434 link berhasil di-scrape.
# 1435 link berhasil di-scrape.
# 1436 link berhasil di-scrape.
# 1437 link berhasil di-scrape.
# 1438 link berhasil di-scrape.
# 1439 link berhasil di-scrape.
# 1440 link berhasil di-scrape.
# 1441 link berhasil di-scrape.
# 1442 link berhasil di-scrape.
# 1443 link berhasil di-scrape.
# 1444 link berhasil di-scrape.
# 1445 link berhasil di-scrape.
# 1446 link berhasil di-scrape.
# 1447 link berhasil di-scrape.
# 1448 link berhasil di-scrape.
# 1449 link berhasil di-scrape.
# 1450 link berhasil di-scrape.
# 1451 link berhasil di-scrape.
# 1452 link berhasil di-scrape.
# 1453 link berhasil di-scrape.
# 1454 link berhasil di-scrape.
# 1455 link berhasil di-scrape.
# 1456 link berhasil di-scrape.
# 1457 link berhasil di-scrape.
# 1458 link berhasil di-scrape.
# 1459 link berhasil di-scrape.
# 1460 link berhasil di-scrape.
# 1461 link berhasil di-scrape.
# 1462 link berhasil di-scrape.
# 1463 link berhasil di-scrape.
# 1464 link berhasil di-scrape.
# 1465 link berhasil di-scrape.
# 1466 link berhasil di-scrape.
# 1467 link berhasil di-scrape.
# 1468 link berhasil di-scrape.
# 1469 link berhasil di-scrape.
# 1470 link berhasil di-scrape.
# 1471 link berhasil di-scrape.
# 1472 link berhasil di-scrape.
# 1473 link berhasil di-scrape.
# 1474 link berhasil di-scrape.
# 1475 link berhasil di-scrape.
# 1476 link berhasil di-scrape.
# 1477 link berhasil di-scrape.
# 1478 link berhasil di-scrape.
# 1479 link berhasil di-scrape.
# 1480 link berhasil di-scrape.
# 1481 link berhasil di-scrape.
# 1482 link berhasil di-scrape.
# 1483 link berhasil di-scrape.
# 1484 link berhasil di-scrape.
# 1485 link berhasil di-scrape.
# 1486 link berhasil di-scrape.
# 1487 link berhasil di-scrape.
# 1488 link berhasil di-scrape.
# 1489 link berhasil di-scrape.
# 1490 link berhasil di-scrape.
# 1491 link berhasil di-scrape.
# 1492 link berhasil di-scrape.
# 1493 link berhasil di-scrape.
# 1494 link berhasil di-scrape.
# 1495 link berhasil di-scrape.
# 1496 link berhasil di-scrape.
# 1497 link berhasil di-scrape.
# 1498 link berhasil di-scrape.
# 1499 link berhasil di-scrape.
# 1500 link berhasil di-scrape.
# 1501 link berhasil di-scrape.
# 1502 link berhasil di-scrape.
# 1503 link berhasil di-scrape.
# 1504 link berhasil di-scrape.
# 1505 link berhasil di-scrape.
# 1506 link berhasil di-scrape.
# 1507 link berhasil di-scrape.
# 1508 link berhasil di-scrape.
# 1509 link berhasil di-scrape.
# 1510 link berhasil di-scrape.
# 1511 link berhasil di-scrape.
# 1512 link berhasil di-scrape.
# 1513 link berhasil di-scrape.
# Scraping selesai dalam 434.72 detik.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Remove punctuations dan angka

# %%
import re
import csv
import pandas as pd

# Membaca file hasil scraping dengan pembatas tanda kutip ganda
data = pd.read_csv("scraped_hewania_articles.csv", quoting=csv.QUOTE_ALL)

# Fungsi untuk membersihkan tanda baca, angka, dan nomor
def clean_text(text):
    # Mengecek apakah teks valid (bukan NaN)
    if isinstance(text, str):  
        text = re.sub(r'[^\w\s]', '', text)  # Menghapus tanda baca
        text = re.sub(r'\d+', '', text)  # Menghapus angka dan nomor
        text = re.sub(r'\s+', ' ', text).strip()  # Menghapus spasi berlebih
        return text
    return text  # Kembalikan teks apa adanya jika bukan string

# Terapkan fungsi pada kolom 'Content' dan 'Judul'
data['Judul_Cleaned'] = data['Judul'].apply(clean_text)
data['Content_Cleaned'] = data['Content'].apply(clean_text)

# Simpan hasilnya kembali ke file CSV tanpa mengubah kolom lama
data.to_csv("cleaned_hewania_articles.csv", index=False, quoting=csv.QUOTE_ALL)

print("Preprocessing Remove punctuations dan nomor, angka selesai dan file hasil telah disimpan.")
# Out:
# Preprocessing Remove punctuations dan nomor, angka selesai dan file hasil telah disimpan.

# %% [markdown]
# ## Menghilangkan stopword

# %%
import pandas as pd
import re

# Membaca file hasil scraping
data = pd.read_csv("cleaned_hewania_articles.csv", quoting=csv.QUOTE_ALL)

# Membaca daftar stopwords dari file stopword.txt
with open('stopword.txt', 'r', encoding='utf-8') as f:
    stopwords = set(f.read().splitlines())

# Fungsi untuk menghapus stopwords dari teks
def remove_stopwords(text):
    if isinstance(text, str):  # Pastikan input adalah string
        words = text.split()
        cleaned_text = ' '.join([word for word in words if word.lower() not in stopwords])
        return cleaned_text
    return text  # Jika bukan string, kembalikan nilai aslinya

# Terapkan fungsi ke kolom 'Judul' dan 'Content'
data['Judul_Cleaned'] = data['Judul_Cleaned'].apply(remove_stopwords)
data['Content_Cleaned'] = data['Content_Cleaned'].apply(remove_stopwords)


# Menyimpan hasil yang sudah diolah ke file CSV baru
data.to_csv("cleaned_hewania_articles.csv", index=False, quoting=csv.QUOTE_ALL)

print("Preprocessing Remove Stopword selesai dan file hasil telah disimpan.")
# Out:
# Preprocessing Remove Stopword selesai dan file hasil telah disimpan.

# %% [markdown]
# ### Case Folding

# %%
import pandas as pd
import csv

# Membaca file hasil scraping
data = pd.read_csv("cleaned_hewania_articles.csv", quoting=csv.QUOTE_ALL)

# Melakukan case folding (mengubah ke huruf kecil) pada kolom Judul dan Content
data['Judul_Cleaned'] = data['Judul_Cleaned'].str.lower()
data['Content_Cleaned'] = data['Content_Cleaned'].str.lower()

# Menyimpan kembali file CSV dengan perubahan pada kolom Judul dan Content
data.to_csv("cleaned_hewania_articles.csv", index=False, quoting=csv.QUOTE_ALL)

print("Case folding telah selesai dan hasilnya telah ditimpa pada kolom Judul dan Content.")
# Out:
# Case folding telah selesai dan hasilnya telah ditimpa pada kolom Judul dan Content.

# %% [markdown]
# ### Stemming

# %%
import pandas as pd
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import csv
import time 

# Membaca file 
data = pd.read_csv("cleaned_hewania_articles.csv", quoting=csv.QUOTE_ALL)

# Membuat objek Stemmer dari Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Fungsi untuk melakukan stemming pada kolom tertentu
def apply_stemming(column_data):
    # Menggunakan list comprehension untuk lebih cepat daripada apply
    return column_data.apply(lambda x: stemmer.stem(x) if isinstance(x, str) else x)

# Memeriksa dan memastikan kolom yang digunakan berisi string
data['Judul_Cleaned'] = data['Judul_Cleaned'].astype(str)
data['Content_Cleaned'] = data['Content_Cleaned'].astype(str)

# Mulai pengukuran waktu
start_time = time.time()

# Melakukan stemming pada kolom Judul_Cleaned dan Content_Cleaned
data['Judul_Cleaned'] = apply_stemming(data['Judul_Cleaned'])
print("Kolom judul berhasil")
data['Content_Cleaned'] = apply_stemming(data['Content_Cleaned'])
print("Kolom konten berhasil")

# Menyimpan kembali file CSV dengan perubahan pada kolom Judul dan Content
data.to_csv("cleaned_hewania_articles_stemmed.csv", index=False, quoting=csv.QUOTE_ALL)

# Menghitung waktu yang telah berlalu
end_time = time.time()
execution_time = end_time - start_time

print(f"Stemming telah selesai dan hasilnya telah disimpan pada file baru.")
print(f"Waktu yang dibutuhkan untuk proses stemming: {execution_time:.2f} detik.")
# Out:
# Kolom judul berhasil
# Kolom konten berhasil
# Stemming telah selesai dan hasilnya telah disimpan pada file baru.
# Waktu yang dibutuhkan untuk proses stemming: 573.18 detik.

# %% [markdown]
# ### Tokenisasi

# %%
import pandas as pd
import csv

# Membaca file
data = pd.read_csv("cleaned_hewania_articles_stemmed.csv", quoting=csv.QUOTE_ALL)

# Fungsi untuk melakukan tokenisasi sederhana
def apply_tokenization(column_data):
    return column_data.apply(lambda x: x.split() if isinstance(x, str) else x)

# Tokenisasi pada kolom Judul_Cleaned dan Content_Cleaned
data['Judul_Cleaned'] = apply_tokenization(data['Judul_Cleaned'])
data['Content_Cleaned'] = apply_tokenization(data['Content_Cleaned'])

# Menyimpan kembali file CSV dengan perubahan pada kolom Judul_Cleaned dan Content_Cleaned
data.to_csv("cleaned_hewania_articles_tokenized.csv", index=False, quoting=csv.QUOTE_ALL)

print("Tokenisasi selesai dan hasilnya telah disimpan pada file baru.")
# Out:
# Tokenisasi selesai dan hasilnya telah disimpan pada file baru.

# %% [markdown]
# ## Membuat Search Engine menggunakan algoritma Cosine Similarity & Jaccard Similarity

# %%
#membuat file bernama app.py dengan isi sebagai berikut:

from flask import Flask, render_template, request
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

app = Flask(__name__)

# Inisialisasi stemmer Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Load data
df = pd.read_csv("cleaned_hewania_articles_tokenized.csv")
df.fillna("", inplace=True)

# Gabungkan kolom judul dan konten untuk perhitungan
df["combined"] = df["Judul_Cleaned"] + " " + df["Content_Cleaned"]

# Load stopwords
with open("stopword.txt", "r") as file:
    stopwords = set(file.read().splitlines())

# Fungsi preprocessing
def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Hilangkan angka dan tanda baca
    text = re.sub(r"[^\w\s]", "", text)
    text = re.sub(r"\d+", "", text)
    # Tokenisasi dan hapus stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stopwords]
    return " ".join(tokens)

# Fungsi untuk melakukan stemming pada query menggunakan Sastrawi
def stem_query(query):
    return stemmer.stem(query)  # Terapkan stemming pada query

# Fungsi Cosine Similarity
def get_cosine_similarity(query, top_n=20):
    query = preprocess_text(query)
    query = stem_query(query)  # Terapkan stemming pada query
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform([query] + df["combined"].tolist())
    cosine_sim = cosine_similarity(vectors[0:1], vectors[1:]).flatten()
    
    results = []
    for idx, cosine_score in enumerate(cosine_sim):
        results.append({
            "index": idx,
            "title": df.loc[idx, "Judul"],
            "link": df.loc[idx, "Link"],
            "date": df.loc[idx, "Tanggal"],
            "content": df.loc[idx, "Content"][:200] + "...",
            "image": df.loc[idx, "Image URL"],
            "cosine_similarity": cosine_score,
        })
    
    results = sorted(results, key=lambda x: x["cosine_similarity"], reverse=True)
    return results[:top_n]

# Fungsi Jaccard Similarity
def get_jaccard_similarity(query, top_n=20):
    query = preprocess_text(query)  # Preprocessing untuk query
    query = stem_query(query)  # Terapkan stemming pada query
    query_tokens = set(query.split())  # Tokenkan query
    
    results = []
    for idx, row in df.iterrows():
        # Preprocessing hanya dilakukan di Jaccard
        doc_tokens = set(preprocess_text(row["combined"]).split())  # Preprocess langsung
        
        # Hitung Jaccard Similarity
        intersection = len(query_tokens & doc_tokens)
        union = len(query_tokens | doc_tokens)
        jaccard_score = intersection / union if union != 0 else 0
        
        results.append({
            "index": idx,
            "title": row["Judul"],
            "link": row["Link"],
            "date": row["Tanggal"],
            "content": row["Content"][:200] + "...",
            "image": row["Image URL"],
            "jaccard_similarity": jaccard_score,
        })
    
    results = sorted(results, key=lambda x: x["jaccard_similarity"], reverse=True)
    return results[:top_n]

# Route index - Menampilkan artikel terbaru
@app.route('/')
def index():
    # Ambil artikel terbaru (misalnya 3 artikel terbaru berdasarkan tanggal)
    latest_articles = df.sort_values(by='Tanggal', ascending=False).head(3)
    
    # Konversi DataFrame menjadi list of dictionaries
    latest_articles_dict = latest_articles.to_dict(orient='records')
    
    # Render template dengan data artikel terbaru
    return render_template('index.html', latest_articles=latest_articles_dict)

# Route search
@app.route('/search', methods=['GET', 'POST'])
def search():
    query = request.form.get('query', '') if request.method == 'POST' else request.args.get('query', '')
    algorithm = request.form.get('algorithm', 'cosine') if request.method == 'POST' else request.args.get('algorithm', 'cosine')
    page = int(request.args.get('page', 1))
    per_page = 10
    
    if algorithm == 'cosine':
        all_results = get_cosine_similarity(query, top_n=30)
    elif algorithm == 'jaccard':
        all_results = get_jaccard_similarity(query, top_n=30)
    else:
        all_results = []
    
    # Filter out results with a score of 0
    filtered_results = [result for result in all_results if (result.get('cosine_similarity', 0) > 0 or result.get('jaccard_similarity', 0) > 0)]
    
    total_results = len(filtered_results)
    total_pages = (total_results + per_page - 1) // per_page
    page = max(1, min(page, total_pages))
    start = (page - 1) * per_page
    end = start + per_page
    results = filtered_results[start:end]
    
    return render_template(
        'results.html',
        query=query,
        results=results,
        algorithm=algorithm,
        page=page,
        total_pages=total_pages,
        total_results=total_results
    )

if __name__ == '__main__':
    app.run(debug=True)

# %%
# !python app.py
